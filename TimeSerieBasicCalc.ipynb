# %% [markdown]
# # Statistics Introduction Applied to Data Science
# ## Bonus : Two - Time Series

# %% [markdown]
# ### Basic Time Series Calculations

# %% [markdown]
# * shift(): Moving data between past and future.
# * div() : Calculate one period percent change.
# * diff(): Built-in time series change.
# * pct_change(): Built-in time series % change.
# * Multi-periods returns.

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('YesBank_StockPrices.csv', sep=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 185 entries, 0 to 184
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 7.4+ KB

# %%
df.head(3)
# Out:
#      Date   Open   High    Low  Close
# 0  Jul-05  13.00  14.00  11.25  12.46
# 1  Aug-05  12.58  14.88  12.55  13.42
# 2  Sep-05  13.48  14.87  12.27  13.30

# %%
df.tail(3)
# Out:
#        Date   Open   High    Low  Close
# 182  Sep-20  14.30  15.34  12.75  13.15
# 183  Oct-20  13.30  14.01  12.11  12.42
# 184  Nov-20  12.41  14.90  12.21  14.67

# %%
# You can create a sequences of dates and times
idx = pd.date_range(start='2005-07', end='2020-12', freq='M')
idx
# Out:
# DatetimeIndex(['2005-07-31', '2005-08-31', '2005-09-30', '2005-10-31',
#                '2005-11-30', '2005-12-31', '2006-01-31', '2006-02-28',
#                '2006-03-31', '2006-04-30',
#                ...
#                '2020-02-29', '2020-03-31', '2020-04-30', '2020-05-31',
#                '2020-06-30', '2020-07-31', '2020-08-31', '2020-09-30',
#                '2020-10-31', '2020-11-30'],
#               dtype='datetime64[ns]', length=185, freq='M')

# %%
# Add DatetimeIndex to dataframe
df.set_index(idx, inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 185 entries, 2005-07-31 to 2020-11-30
# Freq: M
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    185 non-null    object
#  1   Open    185 non-null    float64
#  2   High    185 non-null    float64
#  3   Low     185 non-null    float64
#  4   Close   185 non-null    float64
# dtypes: float64(4), object(1)
# memory usage: 8.7+ KB

# %%
df.head()
# Out:
#               Date   Open   High    Low  Close
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41

# %% [markdown]
# ### .shift(): Moving data between past & future

# %%
df['Close_Shifted'] = df.Close.shift() # default: periods=1
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99

# %%
df['Close_Lagged'] = df.Close.shift(periods=-1)
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71

# %%
df.tail()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged
# 2020-07-31  Jul-20  25.60  28.30  11.10  11.95          25.60         14.37
# 2020-08-31  Aug-20  12.00  17.16  11.85  14.37          11.95         13.15
# 2020-09-30  Sep-20  14.30  15.34  12.75  13.15          14.37         12.42
# 2020-10-31  Oct-20  13.30  14.01  12.11  12.42          13.15         14.67
# 2020-11-30  Nov-20  12.41  14.90  12.21  14.67          12.42           NaN

# %% [markdown]
# ### Calculate one-period percent change

# %%
df['change'] = df.Close.div(df.Close_Shifted)
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged  \
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71
#
#               change
# 2005-07-31       NaN
# 2005-08-31  1.077047
# 2005-09-30  0.991058
# 2005-10-31  0.976692
# 2005-11-30  1.032333

# %%
# You can chain all DataFrame methods that return a DataFrame. The return DataFrame will be used as input for the next
# calculation.
# Example: Subtracting 1 and multiplying the result by 100 to obtain the relative change in percentage terms.

df['return'] = df.change.sub(1).mul(100)
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged  \
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71
#
#               change    return
# 2005-07-31       NaN       NaN
# 2005-08-31  1.077047  7.704655
# 2005-09-30  0.991058 -0.894188
# 2005-10-31  0.976692 -2.330827
# 2005-11-30  1.032333  3.233256

# %% [markdown]
# ### diff(): built-in time-series change

# %%
# xt -x(t-1)
# Calculates the change between values at different points in time.
df['diff_Close'] = df.Close.diff()
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged  \
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71
#
#               change    return  diff_Close
# 2005-07-31       NaN       NaN         NaN
# 2005-08-31  1.077047  7.704655        0.96
# 2005-09-30  0.991058 -0.894188       -0.12
# 2005-10-31  0.976692 -2.330827       -0.31
# 2005-11-30  1.032333  3.233256        0.42

# %% [markdown]
# ### pct_change(): built-in time-series % change

# %%
# Percent change for two adjacent periodos
# xt / x(t-1)
df['pct_Close'] = df.Close.pct_change().mul(100)
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged  \
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71
#
#               change    return  diff_Close  pct_Close
# 2005-07-31       NaN       NaN         NaN        NaN
# 2005-08-31  1.077047  7.704655        0.96   7.704655
# 2005-09-30  0.991058 -0.894188       -0.12  -0.894188
# 2005-10-31  0.976692 -2.330827       -0.31  -2.330827
# 2005-11-30  1.032333  3.233256        0.42   3.233256

# %% [markdown]
# ### Looking ahead: Get multi-period returns

# %%
df['Close_3d'] = df.Close.pct_change(periods=3).mul(100)
df.head()
# Out:
#               Date   Open   High    Low  Close  Close_Shifted  Close_Lagged  \
# 2005-07-31  Jul-05  13.00  14.00  11.25  12.46            NaN         13.42
# 2005-08-31  Aug-05  12.58  14.88  12.55  13.42          12.46         13.30
# 2005-09-30  Sep-05  13.48  14.87  12.27  13.30          13.42         12.99
# 2005-10-31  Oct-05  13.20  14.47  12.40  12.99          13.30         13.41
# 2005-11-30  Nov-05  13.35  13.88  12.88  13.41          12.99         13.71
#
#               change    return  diff_Close  pct_Close  Close_3d
# 2005-07-31       NaN       NaN         NaN        NaN       NaN
# 2005-08-31  1.077047  7.704655        0.96   7.704655       NaN
# 2005-09-30  0.991058 -0.894188       -0.12  -0.894188       NaN
# 2005-10-31  0.976692 -2.330827       -0.31  -2.330827  4.253612
# 2005-11-30  1.032333  3.233256        0.42   3.233256 -0.074516

# %%
# End
